# %%
import pandas as pd

with open('F:\\AI-dataset\\GTSRB\\signnames.csv') as f:
    signnames = pd.read_csv(f, sep=',')
signnames.head(43)
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# ...

# %%
signnames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ClassId   43 non-null     int64
#  1   SignName  43 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 816.0+ bytes

# %%
signnames.describe()
# Out:
#          ClassId
# count  43.000000
# mean   21.000000
# std    12.556539
# min     0.000000
# 25%    10.500000
# 50%    21.000000
# 75%    31.500000
# max    42.000000

# %%
for i in iter(signnames.SignName):
    print(i)
# Out:
# Speed limit (20km/h)
# Speed limit (30km/h)
# Speed limit (50km/h)
# Speed limit (60km/h)
# Speed limit (70km/h)
# Speed limit (80km/h)
# End of speed limit (80km/h)
# Speed limit (100km/h)
# Speed limit (120km/h)
# No passing
# No passing for vechiles over 3.5 metric tons
# Right-of-way at the next intersection
# Priority road
# Yield
# Stop
# No vechiles
# Vechiles over 3.5 metric tons prohibited
# No entry
# General caution
# Dangerous curve to the left
# Dangerous curve to the right
# Double curve
# Bumpy road
# Slippery road
# Road narrows on the right
# Road work
# Traffic signals
# Pedestrians
# Children crossing
# Bicycles crossing
# Beware of ice/snow
# Wild animals crossing
# End of all speed and passing limits
# Turn right ahead
# Turn left ahead
# Ahead only
# Go straight or right
# Go straight or left
# Keep right
# Keep left
# Roundabout mandatory
# End of no passing
# End of no passing by vechiles over 3.5 metric tons

# %%
list(signnames['SignName'])
# Out:
# ['Speed limit (20km/h)',
#  'Speed limit (30km/h)',
#  'Speed limit (50km/h)',
#  'Speed limit (60km/h)',
#  'Speed limit (70km/h)',
#  'Speed limit (80km/h)',
#  'End of speed limit (80km/h)',
#  'Speed limit (100km/h)',
#  'Speed limit (120km/h)',
#  'No passing',
#  'No passing for vechiles over 3.5 metric tons',
#  'Right-of-way at the next intersection',
#  'Priority road',
#  'Yield',
#  'Stop',
#  'No vechiles',
#  'Vechiles over 3.5 metric tons prohibited',
#  'No entry',
#  'General caution',
#  'Dangerous curve to the left',
#  'Dangerous curve to the right',
#  'Double curve',
#  'Bumpy road',
#  'Slippery road',
#  'Road narrows on the right',
#  'Road work',
#  'Traffic signals',
#  'Pedestrians',
#  'Children crossing',
#  'Bicycles crossing',
#  'Beware of ice/snow',
#  'Wild animals crossing',
#  'End of all speed and passing limits',
#  'Turn right ahead',
#  'Turn left ahead',
#  'Ahead only',
#  'Go straight or right',
#  'Go straight or left',
#  'Keep right',
# ...

# %%
h5 = pd.read_hdf(r'F:\AI-modelsaver\GTSRB\LeNet5\2020-08-10\14-33-51\ModelCheckPoint\ep030-loss0.286-val_loss0.744-acc0.913-val_acc0.807.h5')
h5.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-8e643b6a9b82> in <module>
# ----> 1 h5 = pd.read_hdf(r'F:\AI-modelsaver\GTSRB\LeNet5\2020-08-10\14-33-51\ModelCheckPoint\ep030-loss0.286-val_loss0.744-acc0.913-val_acc0.807.h5')
#       2 h5.info()
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     389             if len(groups) == 0:
#     390                 raise ValueError(
# --> 391                     "Dataset(s) incompatible with Pandas data types, "
#     392                     "not table, or no datasets found in HDF5 file."
#     393                 )
#
# ValueError: Dataset(s) incompatible with Pandas data types, not table, or no datasets found in HDF5 file.
